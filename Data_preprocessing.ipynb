# %%
# 将下面这部分 JSON 格式的字典中的 "null" 替换为 None
{
    "cell_type": "code",
    "execution_count": None,  # 将 null 改为 None
    "metadata": {},
    "outputs": [],
    "source": []
}
# Out:
# {'cell_type': 'code',
#  'execution_count': None,
#  'metadata': {},
#  'outputs': [],
#  'source': []}

# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd
import os
# 获取当前文件所在的目录路径
current_directory = os.path.dirname(__file__)

# 构建数据文件的路径
file1_path = os.path.join(current_directory, "../data/accepted_2007_to_2018q4.csv", "accepted_2007_to_2018q4.csv")

print("1")
# 读取file1.csv
#file1_path = 'D:/bristol/study/subjects/individual project/data_lendingclub/2/archive/accepted_2007_to_2018q4.csv/accepted_2007_to_2018q4.csv'
data1 = pd.read_csv(file1_path)
print("2")
# 添加新列，并填充为1
data1['New_Column_statement'] = 1
print("3")
# 保存修改后的data1
data1.to_csv('processing_data1.csv', index=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
current_directory = os.path.dirname(__file__)
print("4")
# 构建数据文件的路径
file2_path = os.path.join(current_directory, "../data/rejected_2007_to_2018q4.csv", "rejected_2007_to_2018q4.csv")

# 读取file2.csv
#file2_path = 'D:/bristol/study/subjects/individual project/data_lendingclub/2/archive/rejected_2007_to_2018q4.csv/rejected_2007_to_2018q4.csv'
data2 = pd.read_csv(file2_path)
print("5")
# 添加新列，并填充为0
data2['New_Column_statement'] = 0
print("6")
# 保存修改后的data2
data2.to_csv('processing_data2.csv', index=False)

# %%
# 读取修改后的两个CSV文件
data1_modified = pd.read_csv('processing_data1.csv')
data2_modified = pd.read_csv('processing_data2.csv')
print("7")
# 将两个数据集连接起来
combined_data = pd.concat([data1_modified, data2_modified], ignore_index=True)
print("8")
# 保存连接后的数据为第三个CSV文件
combined_data.to_csv('processing_data.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8744/3145456463.py in <module>
#       4
#       5 # 将两个数据集连接起来
# ----> 6 combined_data = pd.concat([data1_modified, data2_modified], ignore_index=True)
#       7
#       8 # 保存连接后的数据为第三个CSV文件
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     305     )
#     306
# --> 307     return op.get_result()
#     308
#     309
#
# ...

# %%
# 读取CSV文件
data = pd.read_csv('processing_data.csv')

# 显示前几行，默认显示前5行
num_rows_to_display = 5
print(data.head(num_rows_to_display))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.99       123.03     C        C4  ...                            NaN
# ...

# %%
# # 从CSV文件读取数据并进行数据处理
# def process_data(csv_file):
#     # 从CSV文件读取数据
#     data = pd.read_csv(csv_file)
#         # The length of the data
#     print(f"The Length of the data: {data.shape}")
#     for column in data.columns:
#         if data[column].isna().sum() != 0:
#             missing = data[column].isna().sum()
#             portion = (missing / data.shape[0]) * 100
#             print(f"'{column}': number of missing values '{missing}' ==> '{portion:.3f}%'")
#             if portion >=90:
#                 data.drop(column, axis=1, inplace=True) #delete the almost empty columns
    

#     #delete the empty rows
#     print(data.info(verbose=True, null_counts=True))
#     data=data.dropna(axis=0, how='all', inplace=False)


#     # 在这里进行数据处理（示例：假设需要删除一列"column_to_remove"）
#     # if "column_to_remove" in data.columns:
#     #     data = data.drop(columns=["column_to_remove"])

#     # 在这里可以添加其他的数据处理操作

#     return data

# %%
# def save_processed_data_to_csv(processed_data, csv_file):
#     processed_data.to_csv(csv_file, index=False)

# # 指定原始CSV文件路径和要保存的处理后CSV文件路径
# original_csv_file = "D:/bristol/study/subjects/individual project/data_lendingclub/5/archive/loan.csv"
# processed_csv_file = "D:/bristol/study/subjects/individual project/data_lendingclub/5/archive/processed_loan.csv"

# # 进行数据处理
# processed_data = process_data(original_csv_file)

# # 将处理后的数据保存为另一个CSV文件
# save_processed_data_to_csv(processed_data, processed_csv_file)
# Out:
# C:\Users\lin\AppData\Local\Temp/ipykernel_8744/3264730275.py:9: DtypeWarning: Columns (19,47,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types.Specify dtype option on import or set low_memory=False.
#   processed_data = process_data(original_csv_file)
# The Length of the data: (2260668, 145)
# 'id': number of missing values '2260668' ==> '100.000%'
# 'member_id': number of missing values '2260668' ==> '100.000%'
# 'emp_title': number of missing values '166969' ==> '7.386%'
# 'emp_length': number of missing values '146907' ==> '6.498%'
# 'annual_inc': number of missing values '4' ==> '0.000%'
# 'url': number of missing values '2260668' ==> '100.000%'
# 'desc': number of missing values '2134601' ==> '94.423%'
# 'title': number of missing values '23325' ==> '1.032%'
# 'zip_code': number of missing values '1' ==> '0.000%'
# 'dti': number of missing values '1711' ==> '0.076%'
# 'delinq_2yrs': number of missing values '29' ==> '0.001%'
# ...

# %%
# # 从CSV文件读取数据并转换为NumPy数组
# def read_csv_to_numpy(csv_file):

#     data = np.genfromtxt(csv_file, delimiter=',', dtype=None, encoding='utf-8')
#     return data

# # 保存NumPy数组到npz文件
# def save_numpy_to_npz(numpy_array, npz_file):
#     np.savez(npz_file, data=numpy_array)

# %%
# # 指定CSV文件路径和要保存的npz文件名
# processed_csv_file = "D:/bristol/study/subjects/individual project/data_lendingclub/5/archive/processed_loan.csv"
# npz_file = "D:/bristol/study/subjects/individual project/data_lendingclub/5/archive/processed_npz_file.npz"

# # 从CSV文件读取数据并转换为NumPy数组
# numpy_data = read_csv_to_numpy(processed_csv_file)

# # 保存NumPy数组到npz文件
# save_numpy_to_npz(numpy_data, npz_file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5892/3220865052.py in <module>
#       4
#       5 # 从CSV文件读取数据并转换为NumPy数组
# ----> 6 numpy_data = read_csv_to_numpy(processed_csv_file)
#       7
#       8 # 保存NumPy数组到npz文件
#
# ~\AppData\Local\Temp/ipykernel_5892/961155286.py in read_csv_to_numpy(csv_file)
#       2 def read_csv_to_numpy(csv_file):
#       3
# ----> 4     data = np.genfromtxt(csv_file, delimiter=',', dtype=None, encoding='utf-8')
#       5     return data
#       6
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, like)
# ...
